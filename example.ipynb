# %%
from IPython.display import SVG, display

from main import main

# %%
print(main(anim=True, seed=43, map_size='huge', egocentric_idx=3))
display(SVG('render.svg'))
# Out:
# {'steps': 99, 'ICR': 1.0, 'CSR': 1, 'duration': 5}
