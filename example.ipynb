# %%
from IPython.display import SVG, display
from main import main

# %%
main(anim=True, seed=12, map_size='hard', egocentric_idx=1)
# Out:
# {'steps': 167, 'CSR': 1, 'ICR': 1.0, 'duration': 57}

# %%
display(SVG('render.svg'))
